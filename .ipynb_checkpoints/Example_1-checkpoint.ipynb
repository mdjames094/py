# %% [markdown]
# # 3 classes and 2 dimensions with 1 HL (Perceptron) and 2 HL (MLP)

# %%
# %run lib/imports.ipynb
# %run lib/functions.ipynb
# %run lib/optimisers.ipynb
# %run lib/batch.ipynb
# %run lib/layers.ipynb
# %run lib/network.ipynb

# %%
# Generate data samples

np.random.seed(0)
N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
X = np.zeros((N*K,D))
y = np.zeros(N*K, dtype='uint8')
for j in range(K):
  ix = range(N*j,N*(j+1))
  r = np.linspace(0.0,1,N) # radius
  t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
  X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
  y[ix] = j

x_train = X.T
y_train = one_hot(y)
y_train = y_train.T

# %%
# 1 HL

nn = Network(loss = LLayer(centropy, centropy_prime), optimiser = SGD(), iterator = BatchIterator(size=64))
nn.add(ZLayer(2, 3, wInit='Xavier', lr_type='exp'))
nn.add(SLayer(softmax, softmax_prime))

nn.fit(x_train, y_train, 100, 1)

print('training accuracy: %.2f' % nn.accuracy(x_train, y))
nn.performance_plot()
nn.boundary_plot(x_train, y)
# Out:
# epoch     0/100   loss: 1.126, acc: 0.211, lr: 0.5000, rg: 0.0000
# epoch    10/100   loss: 0.799, acc: 0.500, lr: 0.1839, rg: 0.0000
# epoch    20/100   loss: 0.758, acc: 0.477, lr: 0.0677, rg: 0.0000
# epoch    30/100   loss: 0.746, acc: 0.492, lr: 0.0249, rg: 0.0000
# epoch    40/100   loss: 0.735, acc: 0.500, lr: 0.0092, rg: 0.0000
# epoch    50/100   loss: 0.742, acc: 0.484, lr: 0.0034, rg: 0.0000
# epoch    60/100   loss: 0.739, acc: 0.504, lr: 0.0012, rg: 0.0000
# epoch    70/100   loss: 0.735, acc: 0.504, lr: 0.0005, rg: 0.0000
# epoch    80/100   loss: 0.734, acc: 0.504, lr: 0.0002, rg: 0.0000
# epoch    90/100   loss: 0.743, acc: 0.496, lr: 0.0001, rg: 0.0000
# training accuracy: 0.49

# %%
# 2 HL

nn = Network(loss = LLayer(centropy, centropy_prime), optimiser = SGD(), iterator = BatchIterator(size=64))
nn.add(ZLayer(2, 100, wInit='He', lr_type='step', rg=.7, rg_type='L2'))
nn.add(ALayer(relu, relu_prime))
nn.add(ZLayer(100, 3))
nn.add(SLayer(softmax, softmax_prime))

nn.fit(x_train, y_train, 5_000, 1)

print('training accuracy: %.3f' % nn.accuracy(x_train, y))
nn.performance_plot()
nn.boundary_plot(x_train, y)
# Out:
# epoch     0/5000   loss: 1.776, acc: 0.449, lr: 0.5000, rg: 0.7000
# epoch   500/5000   loss: 0.282, acc: 0.941, lr: 0.4000, rg: 0.7000
# epoch  1000/5000   loss: 0.229, acc: 0.961, lr: 0.3200, rg: 0.7000
# epoch  1500/5000   loss: 0.230, acc: 0.941, lr: 0.2560, rg: 0.7000
# epoch  2000/5000   loss: 0.187, acc: 0.969, lr: 0.2048, rg: 0.7000
# epoch  2500/5000   loss: 0.174, acc: 0.961, lr: 0.1638, rg: 0.7000
# epoch  3000/5000   loss: 0.171, acc: 0.957, lr: 0.1311, rg: 0.7000
# epoch  3500/5000   loss: 0.164, acc: 0.949, lr: 0.1049, rg: 0.7000
# epoch  4000/5000   loss: 0.144, acc: 0.973, lr: 0.0839, rg: 0.7000
# epoch  4500/5000   loss: 0.137, acc: 0.980, lr: 0.0671, rg: 0.7000
# training accuracy: 0.980
