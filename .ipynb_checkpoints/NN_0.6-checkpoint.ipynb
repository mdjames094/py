# %% [markdown]
# # OBJECTIVE(s)
# ## 1. Define different methods for Weight initialisation
# ### Xavier [ok]
#     - Sigmoid and Tanh activation functions
#     - W ~ N(0; 2 / (Nin + Nout))
#     - Uniform distribution may be used to
# ### He [ok]
#     - ReLU activation function
#     - W ~ N(0; 2 / Nin)
# ## 2. Define differents methods for learning rate
#     - Exponential decay [ok]
#     - Time-based decay [ok]
#     - Step-based decay [ok]
# ## 3. Implement regularization (weights)
#     - L2 regularisatiin [ ]

# %% [markdown]
# # Import packages and set options

# %%
import numpy as np
#from tqdm import tqdm
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('dark_background')
plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

np.set_printoptions(precision=4)

# %% [markdown]
# # Activation and loss functions

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_prime(x):
    return x * (1 - x)

def tanh(x):
    return np.tanh(x)

def tanh_prime(x):
    return 1-np.tanh(x)**2

def relu(x):
    return np.maximum(0, x)

def relu_prime(x):
    return (x > 0) * 1

def softmax(x):
    tmp = np.exp(x)
    return tmp / np.sum(tmp, axis=0, keepdims=True)

def softmax_prime(x):                     # X(n,m) : matrix of softmax probabilities, #n classes, #m samples 
    i = np.eye(x.shape[0])                # Identity matrix with n dimensions
    tmp1 = np.einsum('ij,ik->jik', x, i)  # Matrix of diagolized softmax values (per m)
    tmp2 = np.einsum('ij,kj->jik', x, x)  # Matrix of cross product of softmax values (per m)
    return tmp1 - tmp2 

def centropy(x, y):
    eps = 1e-8
    x = x.clip(min=eps, max=None)
    logp = np.where(y==1, -np.log(x), 0)
    return logp.sum(axis=0)

def centropy_prime(x, y):
    # Averaging is made by calling function
    eps = 1e-8
    x = x.clip(min=eps, max=None)
    return np.where(y==1, -1/x, 0)

def mse(y_pred, y_obs):
    return np.power(y_pred - y_obs, 2)

def mse_prime(y_pred, y_obs):
    # Averaging is made by calling function
    return 2*(y_pred - y_obs)

def one_hot(y): 
    return np.eye(len(set(y)))[y]

# %% [markdown]
# # Layer(s) class

# %%
class Layer:
    def __init__(self) -> None:
        self.params = {}
        self.grads = {}
        self.lr = 0.0
        self.lr_method = None
        self.lambd = 0.0
           
    def forward(self, input_data):
        raise NotImplementedError
    
    def backward(self, grad, alpha):
        raise NotImplementedError
        
class ZLayer(Layer):
    def __init__(self, inSize, outSize, eps_W=1e-2, eps_B=0.0, wInit='Xavier', seed=None, lr=.5, lr_method=None, lambd=0.0):
        super().__init__()
        if seed != None:
            np.random.seed(0)
        if wInit.upper() == 'HE':
            ####### !!!!!!!!! changed for last example. don t worget to change back.
            sigma = np.sqrt(1 / inSize)
        else :
            sigma = np.sqrt(2 / (inSize + outSize))
        self.params['W'] = sigma * np.random.randn(outSize, inSize)
        self.params['B'] = 0.0 * np.random.randn(outSize, 1)
        self.lr = lr
        self.lr_initial = lr
        self.lr_method = lr_method
        self.lambd = lambd
        
    def forward(self, inData):
        self.input = inData
        self.output = np.dot(self.params['W'], self.input) + self.params['B']
        return self.output
        
    def backward(self, outGrad, alpha=1e-0):
        inGrad = np.dot(self.params['W'].T, outGrad)
        self.grads['W'] = np.dot(outGrad, self.input.T) + self.lambd / outGrad.shape[1] * self.params['W']
        self.grads['B'] = np.sum(outGrad, axis=1, keepdims=True)
        return inGrad        
    
class ALayer(Layer):
    def __init__(self, g, gPrime):
        super().__init__()
        self.g = g
        self.gPrime = gPrime

    def forward(self, inData):
        self.input = inData
        self.output = self.g(self.input)
        return self.output

    def backward(self, outGrad):
        return self.gPrime(self.input) * outGrad

class SLayer(ALayer):
    def backward(self, outGrad):
        return np.einsum('jik,kj->ij', self.gPrime(self.output), outGrad)
    
class LLayer(Layer):
    def __init__(self, g, gPrime, eps=1e-8):
        self.g = g
        self.gPrime = gPrime
        self.eps = eps

    def forward(self, pred, obs):
        self.input = pred
        self.output = self.g(pred, obs)
        return self.output

    def backward(self, pred, obs):
        return self.gPrime(pred, obs)

# %% [markdown]
# # Optimiser class

# %%
class Optimiser():
    def step(self, layers):
        raise NotImplementedError
        
class SGD(Optimiser):
    def lr(self, lr, lr_initial, lr_method, epoch, epochs):
        if lr_method == None:
            return lr
        elif lr_method.upper() == 'EXP':
            k = 10 / epochs
            return lr_initial * np.exp(-k * epoch)
        elif lr_method.upper() == 'DECAY':
            decay = lr_initial / epochs
            return lr_initial * 1 / (1 + decay * epoch)
        elif lr_method.upper() == 'STEP':
            drop_rate = .8
            epochs_drop = .1 * epochs
            return lr_initial * np.power(drop_rate, np.floor(epoch / epochs_drop))
        else:
            return lr
            
    def step(self, params, grads, lr):
        for name, param in params.items():
            param -= lr * grads[name]

# %% [markdown]
# # Batch class

# %%
from collections import namedtuple

Batch = namedtuple("Batch", ["x", "y"])

class DataIterator:
    def __call__(self, x, y):
        raise NotImplementedError

class BatchIterator(DataIterator):
    def __init__(self, size=None, shuffle=True):
        self.size = size
        self.shuffle = shuffle
        
    def __call__(self, x, y):
        lenX = x.shape[1]
        if self.size == None or self.size > lenX:
            yield Batch(x, y)
        else :
            if self.shuffle:
                idx = np.random.permutation((lenX))
            for start in range(0, lenX - self.size + 1, self.size):
                if self.shuffle:
                    batch = idx[start:start + self.size]
                else:
                    batch = slice(start, start + self.size)
                yield Batch(x[:, batch], y[:, batch])
            
    def __old(self, x, y):
        starts = np.arange(0, x.shape[1], self.size)
        if self.shuffle:
            np.random.shuffle(starts)
        for start in starts:
            end = start + self.size
            yield Batch(x[:, start:end], y[:, start:end])

# %% [markdown]
# # Network class

# %%
class Network:
    def __init__(self, loss = LLayer(centropy, centropy_prime), optimiser = SGD(), iterator = BatchIterator()):
        self.layers = []
        self.loss = loss
        self.optimiser = optimiser
        self.iterator = iterator
        self.epoch_loss = []
        self.epoch_acc = []
        
    def add(self, layer):
        self.layers.append(layer)

    def forward(self, output):
        for layer in self.layers:
            output = layer.forward(output)
        return output
    
    def backward(self, grad):
        for layer in reversed(self.layers):
            grad = layer.backward(grad)
        return grad
    
    def update_lr(self, epoch, epochs):
        for layer in self.layers:
            if len(layer.params) > 0:
                layer.lr = self.optimiser.lr(layer.lr, layer.lr_initial, layer.lr_method, epoch, epochs)
    
    def l2_loss(self):
        l2_regularization = 0.0
        for layer in self.layers:
            if len(layer.params) > 0:
                W = layer.params['W']
                l2_regularization += layer.lambd * np.sum(np.square(W))
        return l2_regularization
       
    def update_weights(self):
        for layer in self.layers:
            if len(layer.params) > 0:
                self.optimiser.step(layer.params, layer.grads, layer.lr)
        
    def predict(self, x):
        scores = self.forward(x)
        return np.argmax(scores, axis=0)
        
    def accuracy(self, x, y):
        y_pred = self.predict(x)
        return np.mean(y_pred == y)
    
    def boundary_plot(self, x, y, h=.02):
        x_min, x_max = x[0, :].min() - 1, x[0, :].max() + 1
        y_min, y_max = x[1, :].min() - 1, x[1, :].max() + 1
        xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
        x_grid = np.c_[xx.ravel(), yy.ravel()].T
        Z = self.predict(x_grid)
        Z = Z.reshape(xx.shape)
        fig = plt.figure(figsize=(6.7,5))
        plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.6)
        plt.scatter(x[0, :], x[1, :], c=y, s=40, cmap=plt.cm.Spectral)
        plt.title('Decision boundary')
        plt.xlim(xx.min(), xx.max())
        plt.ylim(yy.min(), yy.max())
        
    def performance_plot(self):
        fig, axs = plt.subplots(figsize=(12,4), nrows=1, ncols=2, sharex=True, constrained_layout=True)
        ax = axs[0]
        ax.plot(self.epoch_loss)
        ax.set_title('Loss')
        ax = axs[1]
        ax.plot(self.epoch_acc, label='Acc')
        ax.set_title('Accuracy')
        ax.set_ylim([0, 1])
        plt.show()
        
    def fit(self, x_train, y_train, epochs, verbose=1):
        for epoch in range(epochs):
            epoch_loss = 0.0
            epoch_l2_loss = 0.0
            epoch_acc = 0.0
            for k, batch in enumerate(self.iterator(x_train, y_train)):
                y_pred = self.forward(batch.x)
                epoch_loss += np.sum(self.loss.forward(y_pred, batch.y))
                epoch_l2_loss += self.l2_loss()
                epoch_acc = 1/(k+1) * (np.mean(np.argmax(y_pred, axis=0) == np.argmax(batch.y, axis=0)) + epoch_acc * k)
                grad = self.loss.backward(y_pred, batch.y) / y_pred.shape[1]            
                grad = self.backward(grad)
                self.update_weights()
            
            self.update_lr(epoch, epochs)
            
            epoch_loss /= y_train.shape[1]
            epoch_loss += epoch_l2_loss / (2 * y_train.shape[1])
            self.epoch_loss.append(epoch_loss)
            self.epoch_acc.append(epoch_acc)
        
            if verbose > 1 or (verbose == 1 and epoch % (epochs/10) == 0):
                print('epoch %5.d/%d   loss: %.3f, acc: %.3f, lr: %f' % (epoch, epochs, epoch_loss, epoch_acc, self.layers[0].lr))

# %% [markdown]
# # (1) Simulation 3 classes and 2 dimensions random data with 1 HL (Perceptron) and 2 HL (MLP)

# %%
# Generate data samples

np.random.seed(0)
N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
X = np.zeros((N*K,D))
y = np.zeros(N*K, dtype='uint8')
for j in range(K):
  ix = range(N*j,N*(j+1))
  r = np.linspace(0.0,1,N) # radius
  t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
  X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
  y[ix] = j

x_train = X.T
y_train = one_hot(y)
y_train = y_train.T

# %%
# 1 HL

nn = Network(loss = LLayer(centropy, centropy_prime), optimiser = SGD(), iterator = BatchIterator(size=64))
nn.add(ZLayer(2, 3, wInit='Xavier', lr_method='exp'))
nn.add(SLayer(softmax, softmax_prime))

nn.fit(x_train, y_train, 100, 1)

print('training accuracy: %.2f' % nn.accuracy(x_train, y))
nn.performance_plot()
nn.boundary_plot(x_train, y)
# Out:
# epoch     0/100   loss: 0.908, acc: 0.508, lr: 0.500000
# epoch    10/100   loss: 0.743, acc: 0.516, lr: 0.183940
# epoch    20/100   loss: 0.731, acc: 0.488, lr: 0.067668
# epoch    30/100   loss: 0.711, acc: 0.512, lr: 0.024894
# epoch    40/100   loss: 0.722, acc: 0.484, lr: 0.009158
# epoch    50/100   loss: 0.719, acc: 0.488, lr: 0.003369
# epoch    60/100   loss: 0.724, acc: 0.480, lr: 0.001239
# epoch    70/100   loss: 0.723, acc: 0.480, lr: 0.000456
# epoch    80/100   loss: 0.715, acc: 0.488, lr: 0.000168
# epoch    90/100   loss: 0.710, acc: 0.508, lr: 0.000062
# training accuracy: 0.50

# %%
# 2 HL

nn = Network(loss = LLayer(centropy, centropy_prime), optimiser = SGD(), iterator = BatchIterator(size=64))
nn.add(ZLayer(2, 100, wInit='He', lr_method='step', lambd=.9))
nn.add(ALayer(relu, relu_prime))
nn.add(ZLayer(100, 3))
nn.add(SLayer(softmax, softmax_prime))

nn.fit(x_train, y_train, 1_000, 1)

print('training accuracy: %.3f' % nn.accuracy(x_train, y))
nn.performance_plot()
nn.boundary_plot(x_train, y)
# Out:
# epoch     0/1000   loss: 1.902, acc: 0.430, lr: 0.500000
# epoch   100/1000   loss: 0.475, acc: 0.875, lr: 0.400000
# epoch   200/1000   loss: 0.372, acc: 0.895, lr: 0.320000
# epoch   300/1000   loss: 0.316, acc: 0.914, lr: 0.256000
# epoch   400/1000   loss: 0.305, acc: 0.910, lr: 0.204800
# epoch   500/1000   loss: 0.282, acc: 0.922, lr: 0.163840
# epoch   600/1000   loss: 0.249, acc: 0.953, lr: 0.131072
# epoch   700/1000   loss: 0.240, acc: 0.953, lr: 0.104858
# epoch   800/1000   loss: 0.233, acc: 0.965, lr: 0.083886
# epoch   900/1000   loss: 0.226, acc: 0.945, lr: 0.067109
# training accuracy: 0.960

# %% [markdown]
# # (2) Simulation XOR gate with 1 hidden layer

# %%
np.set_printoptions(precision=4)

x_train = np.array([ [0, 0], [1, 0], [0, 1], [1, 1] ]).T
y = np.array([0,1,1,0])
y_train = one_hot(y).T

nn = Network(loss = LLayer(mse, mse_prime), optimiser = SGD())
nn.add(ZLayer(2, 2, eps_W=1.0, eps_B=1.0))
nn.add(ALayer(tanh, tanh_prime))
nn.add(ZLayer(2, 2, eps_W=1.0, eps_B=1.0))

nn.fit(x_train, y_train, 5_000, 1)

print('\ntraining accuracy: %.3f' % nn.accuracy(x_train, y))
nn.performance_plot()
nn.boundary_plot(x_train, y)

print('\nXtrain\tYpred\t\t\tYtrain')
predicted = nn.forward(x_train)
predicted_01 = np.argmax(predicted, axis=0)
for i in range(x_train.shape[1]):
    print(x_train[:,i].T, '\t', predicted[:,i].T, predicted_01[i], '\t', y_train[:,i].T, y[i])

# %% [markdown]
# # (3) Simulation sensitivy of hidden layer size

# %%
# Generate data samples

import sklearn.datasets
np.random.seed(0)
X, y = sklearn.datasets.make_moons(200, noise=.2)
fig = plt.figure(figsize=(6.7,5))
plt.scatter(X[:,0], X[:, 1], s=40, c=y, cmap=plt.cm.Spectral)

x_train = X.T
y_train = one_hot(y)
y_train = y_train.T

# %%
for n in [1, 3, 10, 50]:
    nn = Network(loss = LLayer(centropy, centropy_prime), optimiser = SGD(), iterator = BatchIterator(size=64))
    nn.add(ZLayer(2, n, eps_W=1/np.sqrt(2)))
    nn.add(ALayer(tanh, tanh_prime))
    nn.add(ZLayer(n, 2, eps_W=1/np.sqrt(n)))
    nn.add(SLayer(softmax, softmax_prime))

    nn.fit(x_train, y_train, 10_000, 0)

    print('training accuracy: %.3f' % nn.accuracy(x_train, y))
    nn.performance_plot()
    nn.boundary_plot(x_train, y)
print('done.')

# %% [markdown]
# # (4) Neural network data points belonging to three classes
# ### https://www.cristiandima.com/neural-networks-from-scratch-in-python

# %%
np.random.seed(1)

# generate three Gaussian clouds each holding 500 points
X1 = np.random.randn(500, 2) + np.array([0, -2])
X2 = np.random.randn(500, 2) + np.array([2, 2])
X3 = np.random.randn(500, 2) + np.array([-2, 2])

# put them all in a big matrix
X = np.vstack([X1, X2, X3])

# generate the one-hot-encodings
labels = np.array([0]*500 + [1]*500 + [2]*500)
T = np.zeros((1500, 3))
for i in range(1500):
    T[i, labels[i]] = 1

# visualize the data
fig = plt.figure(figsize=(6.7,5))
plt.scatter(X[:,0], X[:,1], c=labels, s=100, cmap=plt.cm.Spectral, alpha=0.5)
plt.show()

x_train = X.T
y_train = T.T

# %%
nn = Network(loss = LLayer(centropy, centropy_prime), optimiser = SGD(alpha=1e-2), iterator = BatchIterator(size=None))
nn.add(ZLayer(2, 5))
nn.add(ALayer(tanh, tanh_prime))
nn.add(ZLayer(5, 3))
nn.add(SLayer(softmax, softmax_prime))

nn.fit(x_train, y_train, 5_000, 1)

print('training accuracy: %.3f' % nn.accuracy(x_train, labels))
nn.performance_plot()
nn.boundary_plot(x_train, labels)

# %% [markdown]
# # (5) L2 regularization
# ### https://github.com/Coding-Lane/L2-Regularization

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from data.model_utils import *
train_X = np.loadtxt('data/train_x.csv', delimiter = ',')
train_Y = np.loadtxt('data/train_y.csv', delimiter = ',').reshape(1, train_X.shape[1])
print("Shape of train_X : ", train_X.shape)
print("Shape of train_Y : ", train_Y.shape)
fig = plt.figure(figsize=(6.7,5))
plt.scatter(train_X[0], train_X[1], c=train_Y[0], cmap=plt.cm.Spectral)
plt.show()
def model(X, Y, layers_dims, learning_rate = 0.3, num_iterations = 30000):
    grads = {}
    cost_list = []                            
    m = X.shape[1]                        
    parameters = initialize_parameters(layers_dims)
    for i in range(0, num_iterations):
        a3, cache = forward_propagation(X, parameters)
        cost = cost_function(a3, Y)
        grads = backward_propagation(X, Y, cache)
        parameters = update_parameters(parameters, grads, learning_rate)
        if (i%1000 == 0):
            print("Cost after iteration ", i, " is : ", cost)
            cost_list.append(cost)
    # plot the cost
    fig = plt.figure(figsize=(6.7,5))
    plt.plot(cost_list)
    plt.ylabel('cost')
    plt.xlabel('iterations')
    plt.show()
    return parameters
learning_rate = 0.3
num_iterations = 20000 + 1
layers_dims = [train_X.shape[0], 100, 10, 1]
parameters = model(train_X, train_Y, layers_dims, learning_rate, num_iterations)
accuracy(train_X, train_Y, parameters, "Train")
fig = plt.figure(figsize=(6.7,5))
plt.title("For Training Dataset")
plot_decision_boundary(lambda x: predict_dec(parameters, x.T), train_X, train_Y)
def cost_function_with_L2(A3, Y, parameters, lambd):
    m = Y.shape[1]
    W1 = parameters["W1"]
    W2 = parameters["W2"]
    W3 = parameters["W3"]
    cost = - 1./m * np.sum(Y*np.log(A3) + (1 - Y)*(np.log(1 - A3)))
    L2_regularization_cost = (lambd/(2*m))*(np.sum(np.square(W1)) + np.sum(np.square(W2)) + np.sum(np.square(W2)))
    cost = cost + L2_regularization_cost
    return cost
def backward_propagation_with_L2(X, Y, cache, lambd):
    m = X.shape[1]
    (Z1, A1, W1, b1, Z2, A2, W2, b2, Z3, A3, W3, b3) = cache
    dZ3 = A3 - Y
    dW3 = 1./m * np.dot(dZ3, A2.T) + (lambd*W3)/m
    db3 = 1./m * np.sum(dZ3, axis=1, keepdims = True)
    dA2 = np.dot(W3.T, dZ3)
    dZ2 = np.multiply(dA2, np.int64(A2 > 0))
    dW2 = 1./m * np.dot(dZ2, A1.T) + (lambd*W2)/m
    db2 = 1./m * np.sum(dZ2, axis=1, keepdims = True)
    dA1 = np.dot(W2.T, dZ2)
    dZ1 = np.multiply(dA1, np.int64(A1 > 0))
    dW1 = 1./m * np.dot(dZ1, X.T) + (lambd*W1)/m
    db1 = 1./m * np.sum(dZ1, axis=1, keepdims = True)
    gradients = {"dZ3": dZ3, "dW3": dW3, "db3": db3,
                 "dA2": dA2, "dZ2": dZ2, "dW2": dW2, "db2": db2,
                 "dA1": dA1, "dZ1": dZ1, "dW1": dW1, "db1": db1}
    return gradients
def model_with_L2(X, Y, layers_dims, learning_rate = 0.3, num_iterations = 30000, lambd = 0.7):
    grads = {}
    cost_list = []                            
    m = X.shape[1]                        
    parameters = initialize_parameters(layers_dims)
    for i in range(0, num_iterations):
        a3, cache = forward_propagation(X, parameters)
        cost = cost_function_with_L2(a3, Y, parameters, lambd)
        grads = backward_propagation_with_L2(X, Y, cache, lambd)
        parameters = update_parameters(parameters, grads, learning_rate)
        if (i%1000 == 0):
            print("Cost after iteration ", i, " is : ", cost)
            cost_list.append(cost)
    # plot the cost
    fig = plt.figure(figsize=(6.7,5))
    plt.plot(cost_list)
    plt.ylabel('cost')
    plt.xlabel('iterations')
    plt.show()
    return parameters
learning_rate = 0.3
num_iterations = 20000 + 1
layers_dims = [train_X.shape[0], 100, 10, 1]
parameters = model_with_L2(train_X, train_Y, layers_dims, learning_rate, num_iterations, lambd = 0.1)
accuracy(train_X, train_Y, parameters, "Train")
fig = plt.figure(figsize=(6.7,5))
plt.title("For Training Dataset")
plot_decision_boundary(lambda x: predict_dec(parameters, x.T), train_X, train_Y)
# Out:
# Shape of train_X :  (2, 211)
# Shape of train_Y :  (1, 211)
# Cost after iteration  0  is :  0.695492074816334
# Cost after iteration  1000  is :  0.20184182115796895
# Cost after iteration  2000  is :  0.1844122301308618
# Cost after iteration  3000  is :  0.17136594618276035
# Cost after iteration  4000  is :  0.16284851751502266
# Cost after iteration  5000  is :  0.15486320179656504
# Cost after iteration  6000  is :  0.13690360735336382
# Cost after iteration  7000  is :  0.10807316057918263
# Cost after iteration  8000  is :  0.10393143592175456
# Cost after iteration  9000  is :  0.0902307273079334
# Cost after iteration  10000  is :  0.13936231325701554
# Cost after iteration  11000  is :  0.06927495653013986
# Cost after iteration  12000  is :  nan
# Cost after iteration  13000  is :  nan
# Cost after iteration  14000  is :  nan
# Cost after iteration  15000  is :  nan
# Cost after iteration  16000  is :  nan
# Cost after iteration  17000  is :  nan
# Cost after iteration  18000  is :  nan
# Cost after iteration  19000  is :  nan
# Cost after iteration  20000  is :  nan
# Accuracy of the model on Train dataset is :  96.68 %
# Cost after iteration  0  is :  0.7231520223231983
# Cost after iteration  1000  is :  0.23074438569796527
# Cost after iteration  2000  is :  0.21800085818877235
# Cost after iteration  3000  is :  0.2093704148400595
# Cost after iteration  4000  is :  0.2019267014031992
# Cost after iteration  5000  is :  0.20938009959887496
# Cost after iteration  6000  is :  0.18848327503158857
# Cost after iteration  7000  is :  0.18320321118228364
# Cost after iteration  8000  is :  0.18616390762769694
# Cost after iteration  9000  is :  0.18051432462043743
# Cost after iteration  10000  is :  0.18041310980625777
# Cost after iteration  11000  is :  0.17801410263056436
# Cost after iteration  12000  is :  0.17541556681722595
# Cost after iteration  13000  is :  0.1779422898245662
# Cost after iteration  14000  is :  0.18180425683701512
# Cost after iteration  15000  is :  0.1788517080276843
# Cost after iteration  16000  is :  0.18085643416446678
# Cost after iteration  17000  is :  0.16954716541835205
# Cost after iteration  18000  is :  0.17452705369240817
# Cost after iteration  19000  is :  0.17636257519399615
# Cost after iteration  20000  is :  0.18365343448042218
# Accuracy of the model on Train dataset is :  93.84 %

# %%
train_X = np.loadtxt('data/train_x.csv', delimiter = ',')
train_Y = np.loadtxt('data/train_y.csv', delimiter = ',').reshape(1, train_X.shape[1])
print("Shape of train_X : ", train_X.shape)
print("Shape of train_Y : ", train_Y.shape)

nn = Network(loss = LLayer(centropy, centropy_prime))
nn.add(ZLayer(2, 100, wInit='He', lr=.3))
nn.add(ALayer(relu, relu_prime))
nn.add(ZLayer(100, 10))
nn.add(ALayer(relu, relu_prime))
nn.add(ZLayer(10, 1))
nn.add(ALayer(sigmoid, sigmoid_prime))

nn.fit(train_X, train_Y, 100, 2)
# Out:
# Shape of train_X :  (2, 211)
# Shape of train_Y :  (1, 211)
# epoch     0/100   loss: 0.398, acc: 1.000, lr: 0.300000
# epoch     1/100   loss: 0.519, acc: 1.000, lr: 0.300000
# epoch     2/100   loss: 3.104, acc: 1.000, lr: 0.300000
# epoch     3/100   loss: 9.254, acc: 1.000, lr: 0.300000
# epoch     4/100   loss: 9.254, acc: 1.000, lr: 0.300000
# epoch     5/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch     6/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch     7/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch     8/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch     9/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    10/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    11/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    12/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    13/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    14/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    15/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    16/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    17/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    18/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    19/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    20/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    21/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    22/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    23/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    24/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    25/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    26/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    27/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    28/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    29/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    30/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    31/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    32/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    33/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    34/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    35/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    36/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    37/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    38/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    39/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    40/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    41/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    42/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    43/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    44/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    45/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    46/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    47/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    48/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    49/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    50/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    51/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    52/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    53/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    54/100   loss: nan, acc: 1.000, lr: 0.300000
# /tmp/ipykernel_5278/1592095297.py:2: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# /tmp/ipykernel_5278/1592095297.py:5: RuntimeWarning: overflow encountered in multiply
#   return x * (1 - x)
# /tmp/ipykernel_5278/307106014.py:54: RuntimeWarning: invalid value encountered in multiply
#   return self.gPrime(self.input) * outGrad
# epoch    55/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    56/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    57/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    58/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    59/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    60/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    61/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    62/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    63/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    64/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    65/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    66/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    67/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    68/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    69/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    70/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    71/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    72/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    73/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    74/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    75/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    76/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    77/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    78/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    79/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    80/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    81/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    82/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    83/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    84/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    85/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    86/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    87/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    88/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    89/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    90/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    91/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    92/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    93/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    94/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    95/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    96/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    97/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    98/100   loss: nan, acc: 1.000, lr: 0.300000
# epoch    99/100   loss: nan, acc: 1.000, lr: 0.300000
